# %%
#introduction to tuple datatype:
          #an immutable data type is called as an tuple datatype -----()

# %%
area_size=(10,27)

# %%
print(area_size)
# Out:
# (10, 27)

# %%
type(area_size)
# Out:
# tuple

# %%
area_size[1]=24
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 area_size[1]=24
#
# TypeError: 'tuple' object does not support item assignment

# %%
#introduction to looping statements:
          #introduction to for loop:
#for tempvar in mainvar:
    print(tempvar)

# %%
names=['samrat','chakri','sai','ammu','jaswanth','aswitha']

print(names)
# Out:
# ['samrat', 'chakri', 'sai', 'ammu', 'jaswanth', 'aswitha']

# %%
message= f" god bless you,{names[2].title()}"

print(message)
# Out:
#  god bless you,Sai

# %%
message=f"keep going,{names[0].title()}"

print(message)
# Out:
# keep going,Samrat

# %%
for x in names:
    print(f"god bless you,{x.title()}")
# Out:
# god bless you,Samrat
# god bless you,Chakri
# god bless you,Sai
# god bless you,Ammu
# god bless you,Jaswanth
# god bless you,Aswitha

# %%
for x in names:
    print(f"you got the job,{x.title()}")
    print(f"Time to celebrate tonight,{x.title()}")
# Out:
# you got the job,Samrat
# Time to celebrate tonight,Samrat
# you got the job,Chakri
# Time to celebrate tonight,Chakri
# you got the job,Sai
# Time to celebrate tonight,Sai
# you got the job,Ammu
# Time to celebrate tonight,Ammu
# you got the job,Jaswanth
# Time to celebrate tonight,Jaswanth
# you got the job,Aswitha
# Time to celebrate tonight,Aswitha

# %%
for x in names:
    print(f"you got the job,{x.title()}")
    print(f"Time to celebrate tonight,{x.title()}.\n")
# Out:
# you got the job,Samrat
# Time to celebrate tonight,Samrat.
#
# you got the job,Chakri
# Time to celebrate tonight,Chakri.
#
# you got the job,Sai
# Time to celebrate tonight,Sai.
#
# you got the job,Ammu
# Time to celebrate tonight,Ammu.
#
# you got the job,Jaswanth
# Time to celebrate tonight,Jaswanth.
#
# you got the job,Aswitha
# Time to celebrate tonight,Aswitha.

# %%
print(names)
# Out:
# ['samrat', 'chakri', 'sai', 'ammu', 'jaswanth', 'aswitha']

# %%
for x in names:
print(f"you got the job,{x.title()}")
# Out:
#   Cell In[19], line 2
#     print(f"you got the job,{x.title()}")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
for x in names:
    print(f"you got the job,{x.title()}")
    print(f"Time to celebrate tonight,{x.title()}")
    print("GOD BLESS YOU ALL AND KEEP GOING")
# Out:
# you got the job,Samrat
# Time to celebrate tonight,Samrat
# GOD BLESS YOU ALL AND KEEP GOING
# you got the job,Chakri
# Time to celebrate tonight,Chakri
# GOD BLESS YOU ALL AND KEEP GOING
# you got the job,Sai
# Time to celebrate tonight,Sai
# GOD BLESS YOU ALL AND KEEP GOING
# you got the job,Ammu
# Time to celebrate tonight,Ammu
# GOD BLESS YOU ALL AND KEEP GOING
# you got the job,Jaswanth
# Time to celebrate tonight,Jaswanth
# GOD BLESS YOU ALL AND KEEP GOING
# you got the job,Aswitha
# Time to celebrate tonight,Aswitha
# GOD BLESS YOU ALL AND KEEP GOING
