# %%
#oragnising the list datatype:

# %%
days= ['saturday','monday','wednesday','sunday','thursday','tuesday','friday']

print(days)
# Out:
# ['saturday', 'monday', 'wednesday', 'sunday', 'thursday', 'tuesday', 'friday']

# %%
# i want to organise the list in the alphabetical order...

A-Z (order i want to maintain...!)

# %%
#there are two combinations

# %%
print(sorted(days))           #temp approach
# Out:
# ['friday', 'monday', 'saturday', 'sunday', 'thursday', 'tuesday', 'wednesday']

# %%
print(days)                #original order
# Out:
# ['saturday', 'monday', 'wednesday', 'sunday', 'thursday', 'tuesday', 'friday']

# %%
days.sort()

print(days)
# Out:
# ['friday', 'monday', 'saturday', 'sunday', 'thursday', 'tuesday', 'wednesday']

# %%
#i want to know how many days are there in the list?

# %%
len(days)
# Out:
# 7

# %%
#i want to know get the opposite order of the given list...

Z-A

# %%
days.reverse()

print(days)
# Out:
# ['wednesday', 'tuesday', 'thursday', 'sunday', 'saturday', 'monday', 'friday']

# %%
#introduction to slicing:
   #general syntax of slicing
[start_value:stop_value:step_count]

# %%
friends=['nichitha','anusri','sindhu','jaya','dev','priya','samrat']

print(friends)
# Out:
# ['nichitha', 'anusri', 'sindhu', 'jaya', 'dev', 'priya', 'samrat']

# %%
#req: i want to get sindhu and samrat in the slice..?

# %%
print(friends[2])
# Out:
# sindhu

# %%
print(friends[6])
# Out:
# samrat

# %%
print(friends[2],friends[6])
# Out:
# sindhu samrat

# %%
print(friends[3:6])
# Out:
# ['jaya', 'dev', 'priya']

# %%
print(friends)
# Out:
# ['nichitha', 'anusri', 'sindhu', 'jaya', 'dev', 'priya', 'samrat']
