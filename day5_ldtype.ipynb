# %%
#introduction to number
num= 1

num2= 4

# %%
type(num)
# Out:
# int

# %%
x= 0.1

print(x)
# Out:
# 0.1

# %%
type(x)   #decimal values in the python...
# Out:
# float

# %%
#introduction to list datatype:

# %%
#creating a list

# %%
fruits= ['kivi','banana','apple','grapes','orange']

print(fruits)
# Out:
# ['kivi', 'banana', 'apple', 'grapes', 'orange']

# %%
#adding elements to a list

fruits.append('guava')      
                             #using append
print(fruits)
# Out:
# ['kivi', 'banana', 'apple', 'grapes', 'orange', 'guava']

# %%
# i want to add pomegranate at 3rd index

fruits.insert(3,'pomegranate')
                                      #usind insert
print(fruits)
# Out:
# ['kivi', 'banana', 'apple', 'pomegranate', 'pomegranate', 'grapes', 'orange', 'guava']

# %%
# for deleting three or two different approches

# %%
print(fruits)
# Out:
# ['kivi', 'banana', 'apple', 'pomegranate', 'pomegranate', 'grapes', 'orange', 'guava']

# %%
x =fruits.pop()
                       #temperory deleting 
print(fruits)
# Out:
# ['kivi', 'banana', 'apple', 'pomegranate', 'pomegranate', 'grapes']

# %%
print(x)
# Out:
# orange

# %%
del fruits[2]
               #permenant deleting
print(fruits)
# Out:
# ['kivi', 'banana', 'pomegranate', 'grapes']
