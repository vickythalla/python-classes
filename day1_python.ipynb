# %%
print("hello world")
# Out:
# hello world

# %%
text = "thanks faiyaz sir for guiding us in python programming"
print(text.title())
# Out:
# Thanks Faiyaz Sir For Guiding Us In Python Programming
