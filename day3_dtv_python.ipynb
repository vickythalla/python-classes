# %%
#variables in python:

# %%
x = 3
y = 4

# %%
z = x+y

print(z)
# Out:
# 7

# %%
# rules for declaring variables in python:

# %%
#1 no namespace while declaring the variable name

# %%
first name= "hyderabad"

print(first name)
# Out:
#   Cell In[6], line 1
#     first name= "hyderabad"
#           ^
# SyntaxError: invalid syntax

# %%
firstname= "hyderabad"

print(firstname)
# Out:
# hyderabad

# %%
#2  a variable should not start with a number

# %%
7name = 'vijaya'

print(7name)
# Out:
#   Cell In[7], line 1
#     7name = 'vijaya'
#     ^
# SyntaxError: invalid decimal literal

# %%
name7 = 'vijaya'

print(name7)
# Out:
# vijaya

# %%
#3 a variable name should not contain any special charecters

# %%
name$ = 'dev'

print(name$)
# Out:
#   Cell In[9], line 1
#     name$ = 'dev'
#         ^
# SyntaxError: invalid syntax

# %%
$name = 'dev'

print($name)
# Out:
#   Cell In[10], line 1
#     $name = 'dev'
#     ^
# SyntaxError: invalid syntax

# %%
## data types 
1. string data type:

# %%
name = 'gracy' 
                                    #single quote
print(name)
# Out:
# gracy

# %%
name = "gracy"
                                  #double quote
print(name)
# Out:
# gracy

# %%
#string methods

# %%
type (name)
# Out:
# str

# %%
fullname ='hyderabad city'

print(fullname)
# Out:
# hyderabad city

# %%
print(fullname.title())       #title method
# Out:
# Hyderabad City

# %%
print(fullname.upper())           #capital letters
# Out:
# HYDERABAD CITY

# %%
print(fullname.lower())                          #small letters
# Out:
# hyderabad city
